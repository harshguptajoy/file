# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical

# %%
# Load dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize pixel values to range [0, 1]
x_train = x_train / 255.0
x_test = x_test / 255.0

# One-hot encode labels
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 256s 2us/step

# %%
# Create model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compile model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Display model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 122570 (478.79 KB)
# Trainable params: 122570 (478.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train model
history = model.fit(x_train, y_train, epochs=30, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/30
# 625/625 [==============================] - 23s 36ms/step - loss: 1.5948 - accuracy: 0.4167 - val_loss: 1.3540 - val_accuracy: 0.5240
# Epoch 2/30
# 625/625 [==============================] - 22s 35ms/step - loss: 1.2631 - accuracy: 0.5516 - val_loss: 1.1671 - val_accuracy: 0.5832
# Epoch 3/30
# 625/625 [==============================] - 22s 35ms/step - loss: 1.1167 - accuracy: 0.6049 - val_loss: 1.1156 - val_accuracy: 0.6123
# Epoch 4/30
# 625/625 [==============================] - 22s 35ms/step - loss: 1.0184 - accuracy: 0.6441 - val_loss: 1.0867 - val_accuracy: 0.6246
# Epoch 5/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.9504 - accuracy: 0.6661 - val_loss: 0.9775 - val_accuracy: 0.6611
# Epoch 6/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.8903 - accuracy: 0.6899 - val_loss: 0.9382 - val_accuracy: 0.6821
# Epoch 7/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.8389 - accuracy: 0.7073 - val_loss: 0.9465 - val_accuracy: 0.6726
# Epoch 8/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.7965 - accuracy: 0.7214 - val_loss: 0.8979 - val_accuracy: 0.6874
# Epoch 9/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.7498 - accuracy: 0.7380 - val_loss: 0.8742 - val_accuracy: 0.7040
# Epoch 10/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.7126 - accuracy: 0.7513 - val_loss: 0.8653 - val_accuracy: 0.7025
# Epoch 11/30
# 625/625 [==============================] - 22s 36ms/step - loss: 0.6782 - accuracy: 0.7615 - val_loss: 0.8440 - val_accuracy: 0.7113
# Epoch 12/30
# 625/625 [==============================] - 23s 36ms/step - loss: 0.6454 - accuracy: 0.7742 - val_loss: 0.9265 - val_accuracy: 0.6901
# Epoch 13/30
# 625/625 [==============================] - 23s 37ms/step - loss: 0.6172 - accuracy: 0.7837 - val_loss: 0.8504 - val_accuracy: 0.7220
# Epoch 14/30
# 625/625 [==============================] - 23s 36ms/step - loss: 0.5883 - accuracy: 0.7926 - val_loss: 0.8441 - val_accuracy: 0.7250
# Epoch 15/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.5605 - accuracy: 0.8031 - val_loss: 0.8805 - val_accuracy: 0.7113
# Epoch 16/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.5343 - accuracy: 0.8120 - val_loss: 0.8837 - val_accuracy: 0.7163
# Epoch 17/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.5133 - accuracy: 0.8201 - val_loss: 0.9018 - val_accuracy: 0.7120
# Epoch 18/30
# 625/625 [==============================] - 23s 36ms/step - loss: 0.4851 - accuracy: 0.8273 - val_loss: 0.9065 - val_accuracy: 0.7124
# Epoch 19/30
# 625/625 [==============================] - 22s 36ms/step - loss: 0.4637 - accuracy: 0.8368 - val_loss: 0.9068 - val_accuracy: 0.7252
# Epoch 20/30
# 625/625 [==============================] - 23s 36ms/step - loss: 0.4422 - accuracy: 0.8446 - val_loss: 0.9194 - val_accuracy: 0.7196
# Epoch 21/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.4229 - accuracy: 0.8495 - val_loss: 1.0269 - val_accuracy: 0.7047
# Epoch 22/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.3979 - accuracy: 0.8596 - val_loss: 0.9821 - val_accuracy: 0.7161
# Epoch 23/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.3801 - accuracy: 0.8658 - val_loss: 1.0341 - val_accuracy: 0.7112
# Epoch 24/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.3624 - accuracy: 0.8722 - val_loss: 1.0430 - val_accuracy: 0.7216
# Epoch 25/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.3409 - accuracy: 0.8781 - val_loss: 1.0894 - val_accuracy: 0.7148
# Epoch 26/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.3257 - accuracy: 0.8832 - val_loss: 1.1348 - val_accuracy: 0.7055
# Epoch 27/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.3024 - accuracy: 0.8930 - val_loss: 1.1357 - val_accuracy: 0.7111
# Epoch 28/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.2903 - accuracy: 0.8971 - val_loss: 1.2502 - val_accuracy: 0.6967
# Epoch 29/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.2755 - accuracy: 0.9017 - val_loss: 1.2710 - val_accuracy: 0.6991
# Epoch 30/30
# 625/625 [==============================] - 22s 35ms/step - loss: 0.2590 - accuracy: 0.9099 - val_loss: 1.3721 - val_accuracy: 0.7014

# %%
# Evaluate model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')

# Plot training history
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 1.4258 - accuracy: 0.6890
# Test accuracy: 0.6890000104904175

# %%
# Make predictions
predictions = model.predict(x_test)

# Visualize sample predictions
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i])
    plt.xlabel(np.argmax(predictions[i]))
plt.show()
# Out:
# 313/313 [==============================] - 2s 6ms/step
